# %% [markdown]
# # エージェントデザインパターン

# %%
# %cd ..

# %%
# /home/ubuntu/environment/training-llm-application-development-starter というディレクトリが表示されれば正常です
# !pwd

# %% [markdown]
# ## パッシブゴールクリエイター

# %%
# !python -m app.agent_design_pattern.passive_goal_creator.main --task "カレーライスの作り方"

# %% [markdown]
# ## プロンプト/レスポンス最適化

# %%
# !python -m app.agent_design_pattern.prompt_optimizer.main --task "カレーライスの作り方"

# %%
# !python -m app.agent_design_pattern.response_optimizer.main --task "カレーライスの作り方"

# %% [markdown]
# ## シングルパスプランジェネレーター

# %%
# !python -m app.agent_design_pattern.single_path_plan_generation.main --task "カレーライスの作り方"

# %% [markdown]
# ## セルフリフレクション

# %%
# !python -m app.agent_design_pattern.self_reflection.main --task "カレーライスの作り方"

# %% [markdown]
# ## 役割ベースの協調

# %%
# !python -m app.agent_design_pattern.role_based_cooperation.main --task "カレーライスの作り方"
